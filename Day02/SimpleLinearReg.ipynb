# %% [markdown]
# ### Step 01: Data Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('studentscores.csv')
X = df.iloc[:, :1].values
y = df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state= 0)

# %% [markdown]
# ### Step 02: Fitting Simple Linear Regression Model to the training set

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression = regression.fit(X_train, y_train)

# %% [markdown]
# ### Step 03: Predicting the Result

# %%
y_pred = regression.predict(X_test)

# %% [markdown]
# ### Step 04: Visualization

# %% [markdown]
# ##### Visualizing the Training Results

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regression.predict(X_train), color = "blue")

# %%
plt.scatter(X_test, y_test, color = "red")
plt.plot(X_test, regression.predict(X_test), color = "blue")
